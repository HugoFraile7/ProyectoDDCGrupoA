# %%
import pandas as pd
df = pd.read_csv('C:/Users/alex0/datos_Complejos_proyecto/ProyectoDDCGrupoA/dataraw/Apple_phones_merge.csv')

# %%
df.iloc[[0, 10]].drop_duplicates()
# Out:
#    ID                                       product_name  \
# 0   1  Apple iPhone XR, 64GB, Black - Unlocked (Renewed)
#
#                                         product_link  \
# 0  https://www.amazon.com/Apple-iPhone-XR-Fully-U...
#
#                                           image_link  Price (Dollar)  \
# 0  https://m.media-amazon.com/images/I/717KHGCJ6e...          168.39
#
#    discount_percentage  price_before_discount  rating_out_of_5  \
# 0                 5.93                  179.0              4.4
#
#    number_of_ratings  brand  ...  CPU  Storage (GB) screen_size (Inches)  \
# 0            64918.0  Apple  ...  NaN          64.0                  6.1
#
#                               cellular_technology  model_name cpu_model  \
# 0  LTE, CDMA, EV-DO, UMTS, HSPA, HSDPA, GSM, EDGE   iPhone XR       NaN
#
#                          available_colors  \
# 0  Black, Blue, Coral, Red, White, Yellow
#
#                                               review  timestamp stars
# ...

# %%
import pandas as pd

# Load the data

data = df

# Extract the date from the 'timestamp' column and convert it to a datetime format
# The original format is "Reviewed in the United States on <date>", so we extract the date part
data['timestamp'] = pd.to_datetime(data['timestamp'].str.extract(r'on (.+)')[0], errors='coerce')

# Display the cleaned data to check if the conversion worked
print(data[['timestamp']].head())
# Out:
#    timestamp
# 0 2024-09-06
# 1 2024-09-15
# 2 2024-05-24
# 3 2024-07-10
# 4 2024-08-21

# %%
# Plotting
import pandas as pd
import matplotlib.pyplot as plt


plt.figure(figsize=(12, 6))

# Scatter plot for each model name with a different color
for model in data['model_name'].unique():
    model_data = data[data['model_name'] == "iPhone 13 Pro Max"]
    plt.scatter(model_data['timestamp'], model_data['stars'], label=model, alpha=0.7)

# Formatting the plot
plt.title('Rating Over Time by Model')
plt.xlabel('Timestamp')
plt.ylabel('Rating (out of 5)')
plt.legend(title='Model Name')
plt.grid()
plt.xticks(rotation=45)
plt.tight_layout()

# Show the plot
plt.show()

# %%
df.review.drop_duplicates(inplace=True)
# Out:
# 0       I am a content creator and needed a second pho...
# 1       Got it to replace my 13 year olds xr in a pinc...
# 2       The exterior is in perfect condition and so fa...
# 3       I have had this product for a few years and it...
# 4       Item was received exactly as expected. The pho...
#                               ...
# 2762       Thank you for the great iPhone!!!\r\nRead more
# 2766    This is the second IPhone 15 pro max renewed I...
# 2767    The phone is in perfect condition. Battery liv...
# 2770    Used is something that I have always been hesi...
# 2773    Looks good, works good, takes time to get use ...
# Name: review, Length: 633, dtype: object
