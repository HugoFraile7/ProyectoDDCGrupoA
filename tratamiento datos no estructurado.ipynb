# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv(r'/content/Apple_phones_merge.csv')

# %%
import pandas as pd
from langdetect import detect, DetectorFactory

# Optional: Set seed for reproducibility
DetectorFactory.seed = 0

# Function to detect language
def detect_language(review):
    try:
        return detect(review)
    except:
        return None  # Return None for any errors

# Apply the function to the 'review' column
df['language'] = df['review'].apply(detect_language)

# Display the updated DataFrame
print(df[['review', 'language']].head())
# Out:
#                                               review language
# 0  I am a content creator and needed a second pho...       en
# 1  Got it to replace my 13 year olds xr in a pinc...       en
# 2  The exterior is in perfect condition and so fa...       en
# 3  I have had this product for a few years and it...       en
# 4  Item was received exactly as expected. The pho...       en

# %%
# Get unique countries
unique_countries = df['language'].unique()

# Display the unique countries
print(unique_countries)
# Out:
# ['en' 'es' 'fr' 'af' 'no' 'ur' 'ro' 'ca' 'hr']

# %%
# Contar cuántas filas tienen 'en' en la columna 'language'
count_en = (df['language'] == 'en').sum()

# Mostrar el resultado
print(f'Número de filas con idioma "en": {count_en}')
print(count_en/len(df))
# Out:
# Número de filas con idioma "en": 606
# 0.8547249647390691

# %%
# Filtrar el DataFrame para quedarte solo con las filas donde 'language' es 'en'
df_en = df[df['language'] == 'en']

# %%
df_en['review'] = df_en['review'].str.lower()
# Out:
# <ipython-input-89-0a712bb2c1b1>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_en['review'] = df_en['review'].str.lower()

# %%
from nltk.tokenize.casual import casual_tokenize


df_en['tk_review'] = df_en['review'].apply(casual_tokenize)
# Out:
# <ipython-input-90-15986bdfb14a>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_en['tk_review'] = df_en['review'].apply(casual_tokenize)

# %%
df_en.head(20)
# Out:
#      ID                                       product_name  \
# 0     1  Apple iPhone XR, 64GB, Black - Unlocked (Renewed)
# 1     1  Apple iPhone XR, 64GB, Black - Unlocked (Renewed)
# 2     1  Apple iPhone XR, 64GB, Black - Unlocked (Renewed)
# 3     1  Apple iPhone XR, 64GB, Black - Unlocked (Renewed)
# 4     1  Apple iPhone XR, 64GB, Black - Unlocked (Renewed)
# 5     1  Apple iPhone XR, 64GB, Black - Unlocked (Renewed)
# 6     1  Apple iPhone XR, 64GB, Black - Unlocked (Renewed)
# 80    2  Apple iPhone 11, 64GB, Black - Unlocked (Renewed)
# 81    2  Apple iPhone 11, 64GB, Black - Unlocked (Renewed)
# 82    2  Apple iPhone 11, 64GB, Black - Unlocked (Renewed)
# 83    2  Apple iPhone 11, 64GB, Black - Unlocked (Renewed)
# 84    2  Apple iPhone 11, 64GB, Black - Unlocked (Renewed)
# 85    2  Apple iPhone 11, 64GB, Black - Unlocked (Renewed)
# 87    2  Apple iPhone 11, 64GB, Black - Unlocked (Renewed)
# 88    2  Apple iPhone 11, 64GB, Black - Unlocked (Renewed)
# 89    2  Apple iPhone 11, 64GB, Black - Unlocked (Renewed)
# 160   3  Apple iPhone 12, 64GB, Black - Fully Unlocked ...
# 161   3  Apple iPhone 12, 64GB, Black - Fully Unlocked ...
# 162   3  Apple iPhone 12, 64GB, Black - Fully Unlocked ...
# 163   3  Apple iPhone 12, 64GB, Black - Fully Unlocked ...
#
#                                           product_link  \
# 0    https://www.amazon.com/Apple-iPhone-XR-Fully-U...
# 1    https://www.amazon.com/Apple-iPhone-XR-Fully-U...
# 2    https://www.amazon.com/Apple-iPhone-XR-Fully-U...
# 3    https://www.amazon.com/Apple-iPhone-XR-Fully-U...
# 4    https://www.amazon.com/Apple-iPhone-XR-Fully-U...
# 5    https://www.amazon.com/Apple-iPhone-XR-Fully-U...
# 6    https://www.amazon.com/Apple-iPhone-XR-Fully-U...
# 80   https://www.amazon.com/Apple-iPhone-11-64GB-Bl...
# 81   https://www.amazon.com/Apple-iPhone-11-64GB-Bl...
# 82   https://www.amazon.com/Apple-iPhone-11-64GB-Bl...
# 83   https://www.amazon.com/Apple-iPhone-11-64GB-Bl...
# 84   https://www.amazon.com/Apple-iPhone-11-64GB-Bl...
# 85   https://www.amazon.com/Apple-iPhone-11-64GB-Bl...
# 87   https://www.amazon.com/Apple-iPhone-11-64GB-Bl...
# 88   https://www.amazon.com/Apple-iPhone-11-64GB-Bl...
# 89   https://www.amazon.com/Apple-iPhone-11-64GB-Bl...
# 160  https://www.amazon.com/Apple-iPhone-12-64GB-Bl...
# 161  https://www.amazon.com/Apple-iPhone-12-64GB-Bl...
# 162  https://www.amazon.com/Apple-iPhone-12-64GB-Bl...
# 163  https://www.amazon.com/Apple-iPhone-12-64GB-Bl...
#
#                                             image_link  Price (Dollar)  \
# 0    https://m.media-amazon.com/images/I/717KHGCJ6e...          168.39
# 1    https://m.media-amazon.com/images/I/717KHGCJ6e...          168.39
# 2    https://m.media-amazon.com/images/I/717KHGCJ6e...          168.39
# 3    https://m.media-amazon.com/images/I/717KHGCJ6e...          168.39
# 4    https://m.media-amazon.com/images/I/717KHGCJ6e...          168.39
# 5    https://m.media-amazon.com/images/I/717KHGCJ6e...          168.39
# 6    https://m.media-amazon.com/images/I/717KHGCJ6e...          168.39
# 80   https://m.media-amazon.com/images/I/612kg3rGyY...          230.00
# 81   https://m.media-amazon.com/images/I/612kg3rGyY...          230.00
# 82   https://m.media-amazon.com/images/I/612kg3rGyY...          230.00
# 83   https://m.media-amazon.com/images/I/612kg3rGyY...          230.00
# 84   https://m.media-amazon.com/images/I/612kg3rGyY...          230.00
# 85   https://m.media-amazon.com/images/I/612kg3rGyY...          230.00
# 87   https://m.media-amazon.com/images/I/612kg3rGyY...          230.00
# 88   https://m.media-amazon.com/images/I/612kg3rGyY...          230.00
# 89   https://m.media-amazon.com/images/I/612kg3rGyY...          230.00
# 160  https://m.media-amazon.com/images/I/41bIlvE1rd...          287.00
# 161  https://m.media-amazon.com/images/I/41bIlvE1rd...          287.00
# 162  https://m.media-amazon.com/images/I/41bIlvE1rd...          287.00
# 163  https://m.media-amazon.com/images/I/41bIlvE1rd...          287.00
#
#      discount_percentage  price_before_discount  rating_out_of_5  \
# 0                   5.93                  179.0              4.4
# 1                   5.93                  179.0              4.4
# 2                   5.93                  179.0              4.4
# 3                   5.93                  179.0              4.4
# 4                   5.93                  179.0              4.4
# 5                   5.93                  179.0              4.4
# 6                   5.93                  179.0              4.4
# 80                  0.00                    NaN              4.2
# 81                  0.00                    NaN              4.2
# 82                  0.00                    NaN              4.2
# 83                  0.00                    NaN              4.2
# 84                  0.00                    NaN              4.2
# 85                  0.00                    NaN              4.2
# 87                  0.00                    NaN              4.2
# 88                  0.00                    NaN              4.2
# 89                  0.00                    NaN              4.2
# 160                 0.00                    NaN              4.1
# 161                 0.00                    NaN              4.1
# 162                 0.00                    NaN              4.1
# 163                 0.00                    NaN              4.1
#
#      number_of_ratings  brand  ...  \
# 0              64918.0  Apple  ...
# 1              64918.0  Apple  ...
# 2              64918.0  Apple  ...
# 3              64918.0  Apple  ...
# 4              64918.0  Apple  ...
# 5              64918.0  Apple  ...
# 6              64918.0  Apple  ...
# 80             52613.0  Apple  ...
# 81             52613.0  Apple  ...
# 82             52613.0  Apple  ...
# 83             52613.0  Apple  ...
# 84             52613.0  Apple  ...
# 85             52613.0  Apple  ...
# 87             52613.0  Apple  ...
# 88             52613.0  Apple  ...
# 89             52613.0  Apple  ...
# 160            25403.0  Apple  ...
# 161            25403.0  Apple  ...
# 162            25403.0  Apple  ...
# 163            25403.0  Apple  ...
#
#                                 cellular_technology  model_name cpu_model  \
# 0    LTE, CDMA, EV-DO, UMTS, HSPA, HSDPA, GSM, EDGE   iPhone XR       NaN
# 1    LTE, CDMA, EV-DO, UMTS, HSPA, HSDPA, GSM, EDGE   iPhone XR       NaN
# 2    LTE, CDMA, EV-DO, UMTS, HSPA, HSDPA, GSM, EDGE   iPhone XR       NaN
# 3    LTE, CDMA, EV-DO, UMTS, HSPA, HSDPA, GSM, EDGE   iPhone XR       NaN
# 4    LTE, CDMA, EV-DO, UMTS, HSPA, HSDPA, GSM, EDGE   iPhone XR       NaN
# 5    LTE, CDMA, EV-DO, UMTS, HSPA, HSDPA, GSM, EDGE   iPhone XR       NaN
# 6    LTE, CDMA, EV-DO, UMTS, HSPA, HSDPA, GSM, EDGE   iPhone XR       NaN
# 80                                               4G   iPhone 11       NaN
# 81                                               4G   iPhone 11       NaN
# 82                                               4G   iPhone 11       NaN
# 83                                               4G   iPhone 11       NaN
# 84                                               4G   iPhone 11       NaN
# 85                                               4G   iPhone 11       NaN
# 87                                               4G   iPhone 11       NaN
# 88                                               4G   iPhone 11       NaN
# 89                                               4G   iPhone 11       NaN
# 160                                      5G, 4G LTE   iPhone 12       NaN
# 161                                      5G, 4G LTE   iPhone 12       NaN
# 162                                      5G, 4G LTE   iPhone 12       NaN
# 163                                      5G, 4G LTE   iPhone 12       NaN
#
#                                       available_colors  \
# 0               Black, Blue, Coral, Red, White, Yellow
# 1               Black, Blue, Coral, Red, White, Yellow
# 2               Black, Blue, Coral, Red, White, Yellow
# 3               Black, Blue, Coral, Red, White, Yellow
# 4               Black, Blue, Coral, Red, White, Yellow
# 5               Black, Blue, Coral, Red, White, Yellow
# 6               Black, Blue, Coral, Red, White, Yellow
# 80            Black, Green, Purple, Red, White, Yellow
# 81            Black, Green, Purple, Red, White, Yellow
# 82            Black, Green, Purple, Red, White, Yellow
# 83            Black, Green, Purple, Red, White, Yellow
# 84            Black, Green, Purple, Red, White, Yellow
# 85            Black, Green, Purple, Red, White, Yellow
# 87            Black, Green, Purple, Red, White, Yellow
# 88            Black, Green, Purple, Red, White, Yellow
# 89            Black, Green, Purple, Red, White, Yellow
# 160  (Product)Red, Black, Blue, Green, Purple, Red,...
# 161  (Product)Red, Black, Blue, Green, Purple, Red,...
# 162  (Product)Red, Black, Blue, Green, Purple, Red,...
# 163  (Product)Red, Black, Blue, Green, Purple, Red,...
#
#                                                 review  timestamp stars  \
# 0    i am a content creator and needed a second pho... 2024-09-06   5.0
# 1    got it to replace my 13 year olds xr in a pinc... 2024-09-15   5.0
# 2    the exterior is in perfect condition and so fa... 2024-05-24   5.0
# 3    i have had this product for a few years and it... 2024-07-10   4.0
# 4    item was received exactly as expected. the pho... 2024-08-21   5.0
# 5    i’ve had this phone for a couple years now, it... 2024-09-07   5.0
# 6    hey guys, so i ordered this phone on the 19th ... 2024-09-22   5.0
# 80   i honestly can’t say enough amazing things abo... 2024-09-18   5.0
# 81   okay, it came in a weird packaging so i was su... 2024-09-11   5.0
# 82   the only complaint so far is that the directio... 2024-08-22   5.0
# 83   i recently purchased the iphone 11 256gb renew... 2024-07-29   4.0
# 84   my son's been wanting a iphone for a long time... 2024-09-09   5.0
# 85   i like this phone !! i had a iphone 7 and hear... 2024-09-21   5.0
# 87   iphone arrive fast and secured. phone was clea... 2024-09-20   5.0
# 88   got the colour i wanted. i also saw this a med... 2024-09-17   5.0
# 89   buen producto, hasta ahorita ha salido bueno\n... 2024-09-11   5.0
# 160  for starters; the price on these phones is gre... 2024-02-10   5.0
# 161  i was looking to save money so i took a “risk”... 2024-09-03   5.0
# 162  like the lightness compared to my samsung s24 ... 2024-06-24   4.0
# 163  first of all i bought the phone and the descri... 2024-09-07   3.0
#
#      language            country  \
# 0          en  the United States
# 1          en  the United States
# 2          en  the United States
# 3          en  the United States
# 4          en  the United States
# 5          en  the United States
# 6          en  the United States
# 80         en  the United States
# 81         en  the United States
# 82         en  the United States
# 83         en  the United States
# 84         en  the United States
# 85         en             Canada
# 87         en             Canada
# 88         en             Canada
# 89         en             Mexico
# 160        en  the United States
# 161        en  the United States
# 162        en  the United States
# 163        en  the United States
#
#                                              tk_review
# 0    [i, am, a, content, creator, and, needed, a, s...
# 1    [got, it, to, replace, my, 13, year, olds, xr,...
# 2    [the, exterior, is, in, perfect, condition, an...
# 3    [i, have, had, this, product, for, a, few, yea...
# 4    [item, was, received, exactly, as, expected, ....
# 5    [i, ’, ve, had, this, phone, for, a, couple, y...
# 6    [hey, guys, ,, so, i, ordered, this, phone, on...
# 80   [i, honestly, can, ’, t, say, enough, amazing,...
# 81   [okay, ,, it, came, in, a, weird, packaging, s...
# 82   [the, only, complaint, so, far, is, that, the,...
# 83   [i, recently, purchased, the, iphone, 11, 256g...
# 84   [my, son's, been, wanting, a, iphone, for, a, ...
# 85   [i, like, this, phone, !, !, i, had, a, iphone...
# 87   [iphone, arrive, fast, and, secured, ., phone,...
# 88   [got, the, colour, i, wanted, ., i, also, saw,...
# 89   [buen, producto, ,, hasta, ahorita, ha, salido...
# 160  [for, starters, ;, the, price, on, these, phon...
# 161  [i, was, looking, to, save, money, so, i, took...
# 162  [like, the, lightness, compared, to, my, samsu...
# 163  [first, of, all, i, bought, the, phone, and, t...
#
# [20 rows x 25 columns]

# %%
import nltk
nltk.download('stopwords')
stop_words = nltk.corpus.stopwords.words('english')
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import nltk
nltk.download('stopwords')
stop_words = set(nltk.corpus.stopwords.words('english'))


df_en['tk_review'] = df_en['tk_review'].apply(lambda x: [item for item in x if item not in stop_words])
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# <ipython-input-93-c5360fa0b3ff>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_en['tk_review'] = df_en['tk_review'].apply(lambda x: [item for item in x if item not in stop_words])

# %%
df_en
# Out:
#         ID                                       product_name  \
# 0        1  Apple iPhone XR, 64GB, Black - Unlocked (Renewed)
# 1        1  Apple iPhone XR, 64GB, Black - Unlocked (Renewed)
# 2        1  Apple iPhone XR, 64GB, Black - Unlocked (Renewed)
# 3        1  Apple iPhone XR, 64GB, Black - Unlocked (Renewed)
# 4        1  Apple iPhone XR, 64GB, Black - Unlocked (Renewed)
# ...    ...                                                ...
# 2779  3160  Apple iPhone 15 Pro Max, 512GB, White Titanium...
# 2780  3160  Apple iPhone 15 Pro Max, 512GB, White Titanium...
# 2781  3160  Apple iPhone 15 Pro Max, 512GB, White Titanium...
# 2782  3160  Apple iPhone 15 Pro Max, 512GB, White Titanium...
# 2783  3160  Apple iPhone 15 Pro Max, 512GB, White Titanium...
#
#                                            product_link  \
# 0     https://www.amazon.com/Apple-iPhone-XR-Fully-U...
# 1     https://www.amazon.com/Apple-iPhone-XR-Fully-U...
# 2     https://www.amazon.com/Apple-iPhone-XR-Fully-U...
# 3     https://www.amazon.com/Apple-iPhone-XR-Fully-U...
# 4     https://www.amazon.com/Apple-iPhone-XR-Fully-U...
# ...                                                 ...
# 2779  https://www.amazon.com/Apple-iPhone-512GB-Whit...
# 2780  https://www.amazon.com/Apple-iPhone-512GB-Whit...
# 2781  https://www.amazon.com/Apple-iPhone-512GB-Whit...
# 2782  https://www.amazon.com/Apple-iPhone-512GB-Whit...
# 2783  https://www.amazon.com/Apple-iPhone-512GB-Whit...
#
#                                              image_link  Price (Dollar)  \
# 0     https://m.media-amazon.com/images/I/717KHGCJ6e...          168.39
# 1     https://m.media-amazon.com/images/I/717KHGCJ6e...          168.39
# 2     https://m.media-amazon.com/images/I/717KHGCJ6e...          168.39
# 3     https://m.media-amazon.com/images/I/717KHGCJ6e...          168.39
# 4     https://m.media-amazon.com/images/I/717KHGCJ6e...          168.39
# ...                                                 ...             ...
# 2779  https://m.media-amazon.com/images/I/31Solq9-fs...         1140.01
# 2780  https://m.media-amazon.com/images/I/31Solq9-fs...         1140.01
# 2781  https://m.media-amazon.com/images/I/31Solq9-fs...         1140.01
# 2782  https://m.media-amazon.com/images/I/31Solq9-fs...         1140.01
# 2783  https://m.media-amazon.com/images/I/31Solq9-fs...         1140.01
#
#       discount_percentage  price_before_discount  rating_out_of_5  \
# 0                    5.93                  179.0              4.4
# 1                    5.93                  179.0              4.4
# 2                    5.93                  179.0              4.4
# 3                    5.93                  179.0              4.4
# 4                    5.93                  179.0              4.4
# ...                   ...                    ...              ...
# 2779                 0.00                    NaN              NaN
# 2780                 0.00                    NaN              NaN
# 2781                 0.00                    NaN              NaN
# 2782                 0.00                    NaN              NaN
# 2783                 0.00                    NaN              NaN
#
#       number_of_ratings  brand  ...  \
# 0               64918.0  Apple  ...
# 1               64918.0  Apple  ...
# 2               64918.0  Apple  ...
# 3               64918.0  Apple  ...
# 4               64918.0  Apple  ...
# ...                 ...    ...  ...
# 2779                NaN  Apple  ...
# 2780                NaN  Apple  ...
# 2781                NaN  Apple  ...
# 2782                NaN  Apple  ...
# 2783                NaN  Apple  ...
#
#                                  cellular_technology         model_name  \
# 0     LTE, CDMA, EV-DO, UMTS, HSPA, HSDPA, GSM, EDGE          iPhone XR
# 1     LTE, CDMA, EV-DO, UMTS, HSPA, HSDPA, GSM, EDGE          iPhone XR
# 2     LTE, CDMA, EV-DO, UMTS, HSPA, HSDPA, GSM, EDGE          iPhone XR
# 3     LTE, CDMA, EV-DO, UMTS, HSPA, HSDPA, GSM, EDGE          iPhone XR
# 4     LTE, CDMA, EV-DO, UMTS, HSPA, HSDPA, GSM, EDGE          iPhone XR
# ...                                              ...                ...
# 2779                                              5G  iPhone 15 Pro Max
# 2780                                              5G  iPhone 15 Pro Max
# 2781                                              5G  iPhone 15 Pro Max
# 2782                                              5G  iPhone 15 Pro Max
# 2783                                              5G  iPhone 15 Pro Max
#
#      cpu_model                        available_colors  \
# 0          NaN  Black, Blue, Coral, Red, White, Yellow
# 1          NaN  Black, Blue, Coral, Red, White, Yellow
# 2          NaN  Black, Blue, Coral, Red, White, Yellow
# 3          NaN  Black, Blue, Coral, Red, White, Yellow
# 4          NaN  Black, Blue, Coral, Red, White, Yellow
# ...        ...                                     ...
# 2779       NaN                                     NaN
# 2780       NaN                                     NaN
# 2781       NaN                                     NaN
# 2782       NaN                                     NaN
# 2783       NaN                                     NaN
#
#                                                  review  timestamp stars  \
# 0     i am a content creator and needed a second pho... 2024-09-06   5.0
# 1     got it to replace my 13 year olds xr in a pinc... 2024-09-15   5.0
# 2     the exterior is in perfect condition and so fa... 2024-05-24   5.0
# 3     i have had this product for a few years and it... 2024-07-10   4.0
# 4     item was received exactly as expected. the pho... 2024-08-21   5.0
# ...                                                 ...        ...   ...
# 2779  came in great condition excellent battery life... 2024-09-19   5.0
# 2780  the media could not be loaded.\n              ... 2024-09-27   5.0
# 2781  only complaint is the charger it came with\nre... 2024-09-14   4.0
# 2782  i’ve had this phone for a week now and to be h... 2024-09-21   3.0
# 2783  screen had multiple deep scratches. returned. ... 2024-09-14   1.0
#
#       language            country  \
# 0           en  the United States
# 1           en  the United States
# 2           en  the United States
# 3           en  the United States
# 4           en  the United States
# ...        ...                ...
# 2779        en  the United States
# 2780        en  the United States
# 2781        en  the United States
# 2782        en             Canada
# 2783        en             Canada
#
#                                               tk_review
# 0     [content, creator, needed, second, phone, ., h...
# 1     [got, replace, 13, year, olds, xr, pinch, batt...
# 2     [exterior, perfect, condition, far, ’, operati...
# 3     [product, years, still, runs, well, enough, ke...
# 4     [item, received, exactly, expected, ., phone, ...
# ...                                                 ...
# 2779  [came, great, condition, excellent, battery, l...
# 2780  [media, could, loaded, ., idk, people, talking...
# 2781                   [complaint, charger, came, read]
# 2782  [’, phone, week, honest, ’, good, condition, e...
# 2783  [screen, multiple, deep, scratches, ., returne...
#
# [606 rows x 25 columns]
