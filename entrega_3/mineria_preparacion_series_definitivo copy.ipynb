# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.graphics.tsaplots as sgt
import statsmodels.tsa.stattools as sts
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.ar_model import ar_select_order
from statsmodels.tsa import ar_model
from sklearn.metrics import mean_squared_error
from scipy.stats.distributions import chi2
import warnings

# %%
data= pd.read_csv(r'../dataprocessed/datos_preprocesados_2.csv')
data
# Out:
#          model_name  Price (Dollar)  Storage (GB)  \
# 0         iPhone XS          182.00            64
# 1     iPhone XS Max          234.95            64
# 2    iPhone 15 Plus         1098.95           128
# 3         iPhone 11          599.00            64
# 4     iPhone 12 Pro          840.13           128
# ..              ...             ...           ...
# 585       iPhone XR          168.39            64
# 586       iPhone XR          181.00            64
# 587       iPhone XR          181.00            64
# 588       iPhone XR          168.39            64
# 589       iPhone XR          181.00            64
#
#                                                 review   timestamp  stars  \
# 0    i received the phone within 2 days of ordering...  2022-02-05      1
# 1    6 months later update - still acts like i boug...  2019-12-20      5
# 2    phone is great but the price is $200 above msr...  2023-11-27      1
# 3           fast shipping, very nice phone!\nread more  2020-07-28      5
# 4                amazing defenitly worth it\nread more  2020-11-05      5
# ..                                                 ...         ...    ...
# 585  got it to replace my 13 year olds xr in a pinc...  2024-09-15      5
# 586  my little niece is so inlove with this phone😌 ...  2024-09-18      5
# 587                               great buy\nread more  2024-09-20      5
# 588  hey guys, so i ordered this phone on the 19th ...  2024-09-22      5
# 589  no complaints, arrived in excellent condition ...  2024-09-30      5
#
#                country language  \
# 0    the United States       en
# 1    the United States       en
# 2    the United States       en
# 3    the United States       en
# 4    the United States       en
# ..                 ...      ...
# 585  the United States       en
# 586  the United States       en
# 587  the United States       en
# 588  the United States       en
# 589  the United States       en
#
#                                              tk_review    timestamp_nanosec  \
# 0    ['received', 'phone', 'within', 'day', 'orderi...  1644019200000000000
# 1    ['month', 'later', 'update', 'still', 'act', '...  1576800000000000000
# 2    ['phone', 'great', 'price', '200', 'msrp', 're...  1701043200000000000
# 3        ['fast', 'shipping', 'nice', 'phone', 'read']  1595894400000000000
# 4            ['amazing', 'defenitly', 'worth', 'read']  1604534400000000000
# ..                                                 ...                  ...
# 585  ['got', 'replace', 'year', 'old', 'pinch', 'ba...  1726358400000000000
# 586  ['little', 'niece', 'inlove', 'phone', 'brough...  1726617600000000000
# 587                           ['great', 'buy', 'read']  1726790400000000000
# 588  ['hey', 'guy', 'ordered', 'phone', '19th', 'go...  1726963200000000000
# 589  ['complaint', 'arrived', 'excellent', 'conditi...  1727654400000000000
#
#      normalized_timestamp_nanosec timestamp_formatted
# 0                               0          01/01/1970
# 1                               0          01/01/1970
# 2                               0          01/01/1970
# 3                               0          01/01/1970
# 4                               0          01/01/1970
# ..                            ...                 ...
# 585            157161600000000000          25/12/1974
# 586            157420800000000000          28/12/1974
# 587            157593600000000000          30/12/1974
# 588            157766400000000000          01/01/1975
# 589            158457600000000000          09/01/1975
#
# [590 rows x 12 columns]

# %% [markdown]
# PREPARACIÓN DE DATOS DE SERIES TEMPORALES

# %%
data['timestamp_formatted'] = pd.to_datetime(data['timestamp_formatted'], dayfirst=True)
fecha_inicio = data['timestamp_formatted'].min()
fecha_fin = data['timestamp_formatted'].max()
rango_fechas = pd.date_range(start=fecha_inicio, end=fecha_fin, freq='D')

fechas_completas = pd.DataFrame({'timestamp_formatted': rango_fechas})

datos_completos = fechas_completas.merge(data, on='timestamp_formatted', how='left')

# Identificar los días faltantes
dias_faltantes = datos_completos[datos_completos.isnull().any(axis=1)]['timestamp_formatted']

# Mostrar resultados
if dias_faltantes.empty:
    print("No hay días faltantes en la serie temporal.")
else:
    print(f"Días faltantes detectados: {len(dias_faltantes)}")
    print(dias_faltantes)
# Out:
# Días faltantes detectados: 1437
# 23     1970-01-02
# 24     1970-01-03
# 28     1970-01-06
# 29     1970-01-07
# 31     1970-01-09
#           ...
# 2021   1975-01-04
# 2022   1975-01-05
# 2023   1975-01-06
# 2024   1975-01-07
# 2025   1975-01-08
# Name: timestamp_formatted, Length: 1437, dtype: datetime64[ns]

# %% [markdown]
# 1 Dividí los datos de esta manera para analizar la serie temporal de manera estructurada porque trabajar con intervalos mensuales permite identificar patrones, tendencias y comportamientos recurrentes en la data de manera más clara y eficiente que con datos diarios

# %%
data['timestamp_formatted'] = pd.to_datetime(data['timestamp_formatted'], dayfirst=True)

data['mes'] = data['timestamp_formatted'].dt.to_period('M')

# Calcular métricas básicas por mes
metrics_per_month = data.groupby('mes').agg(
    avg_rating=('stars', 'mean'),  # Promedio de calificaciones
    count_reviews=('review', 'count')  # Número de reseñas
).reset_index()
metrics_per_month['fecha'] = metrics_per_month['mes'].dt.to_timestamp()

metrics_per_month
# Out:
#         mes  avg_rating  count_reviews      fecha
# 0   1970-01    3.687500             32 1970-01-01
# 1   1970-02    3.846154             13 1970-02-01
# 2   1970-03    4.434783             23 1970-03-01
# 3   1970-04    4.617647             34 1970-04-01
# 4   1970-05    3.538462             13 1970-05-01
# 5   1970-06    3.833333             18 1970-06-01
# 6   1970-07    3.936170             94 1970-07-01
# 7   1970-08    4.600000             15 1970-08-01
# 8   1970-09    4.818182             11 1970-09-01
# 9   1970-10    4.555556              9 1970-10-01
# 10  1970-11    4.428571              7 1970-11-01
# 11  1970-12    3.727273             11 1970-12-01
# 12  1971-01    4.181818             11 1971-01-01
# 13  1971-02    3.400000              5 1971-02-01
# 14  1971-03    4.400000              5 1971-03-01
# 15  1971-04    1.000000              1 1971-04-01
# 16  1971-05    4.000000              4 1971-05-01
# 17  1971-07    2.750000              4 1971-07-01
# 18  1971-08    5.000000              2 1971-08-01
# 19  1971-09    3.571429              7 1971-09-01
# 20  1971-10    3.400000              5 1971-10-01
# 21  1971-11    4.000000              2 1971-11-01
# 22  1971-12    4.000000              3 1971-12-01
# 23  1972-01    4.857143              7 1972-01-01
# 24  1972-02    4.444444              9 1972-02-01
# 25  1972-03    4.400000             20 1972-03-01
# 26  1972-04    4.666667              6 1972-04-01
# 27  1972-05    4.500000              8 1972-05-01
# 28  1972-06    4.142857             14 1972-06-01
# 29  1972-07    3.900000             10 1972-07-01
# 30  1972-08    4.166667             12 1972-08-01
# 31  1972-09    3.416667             12 1972-09-01
# 32  1972-10    4.076923             13 1972-10-01
# 33  1972-11    4.238095             21 1972-11-01
# 34  1972-12    4.400000             20 1972-12-01
# 35  1973-01    4.750000              4 1973-01-01
# 36  1973-02    4.333333              3 1973-02-01
# 37  1973-03    5.000000              1 1973-03-01
# 38  1973-04    5.000000              2 1973-04-01
# 39  1973-05    3.666667              3 1973-05-01
# 40  1973-06    3.666667              3 1973-06-01
# 41  1973-07    1.000000              1 1973-07-01
# 42  1973-08    4.833333              6 1973-08-01
# 43  1973-09    4.600000              5 1973-09-01
# 44  1973-10    4.090909             11 1973-10-01
# 45  1973-11    4.625000              8 1973-11-01
# 46  1973-12    4.166667              6 1973-12-01
# 47  1974-01    4.666667              9 1974-01-01
# 48  1974-02    4.642857             14 1974-02-01
# 49  1974-05    1.000000              2 1974-05-01
# 50  1974-06    5.000000              2 1974-06-01
# 51  1974-07    5.000000              1 1974-07-01
# 52  1974-08    4.500000              2 1974-08-01
# 53  1974-09    4.666667              3 1974-09-01
# 54  1974-10    4.000000              5 1974-10-01
# 55  1974-11    4.857143              7 1974-11-01
# 56  1974-12    4.555556              9 1974-12-01
# 57  1975-01    5.000000              2 1975-01-01

# %% [markdown]
# 2 Resolución de datos faltantes:No se trataron explícitamente los datos faltantes porque las herramientas utilizadas (como groupby y agg) manejan automáticamente intervalos vacíos, y el ajuste del modelo SARIMAX generará errores en caso de que faltasen datos, indicando datos completos. Además, las series temporales suelen contener valores para cada intervalo por su naturaleza.

# %%
data = metrics_per_month


data.set_index('fecha', inplace=True)

# Rellenar datos faltantes por interpolación
data = data.resample('MS').mean()  
data['avg_rating'] = data['avg_rating'].interpolate(method='linear')  # Interpolación lineal para calificaciones
data['count_reviews'] = data['count_reviews'].interpolate(method='linear')  # Interpolación lineal para reseñas

data.reset_index(inplace=True)
data['mes'] = data['fecha'].dt.to_period('M')
data
# Out:
#         fecha      mes  avg_rating  count_reviews
# 0  1970-01-01  1970-01    3.687500           32.0
# 1  1970-02-01  1970-02    3.846154           13.0
# 2  1970-03-01  1970-03    4.434783           23.0
# 3  1970-04-01  1970-04    4.617647           34.0
# 4  1970-05-01  1970-05    3.538462           13.0
# ..        ...      ...         ...            ...
# 56 1974-09-01  1974-09    4.666667            3.0
# 57 1974-10-01  1974-10    4.000000            5.0
# 58 1974-11-01  1974-11    4.857143            7.0
# 59 1974-12-01  1974-12    4.555556            9.0
# 60 1975-01-01  1975-01    5.000000            2.0
#
# [61 rows x 4 columns]

# %%
metrics_per_month = data.copy(deep=True)
metrics_per_month
# Out:
#         fecha      mes  avg_rating  count_reviews
# 0  1970-01-01  1970-01    3.687500           32.0
# 1  1970-02-01  1970-02    3.846154           13.0
# 2  1970-03-01  1970-03    4.434783           23.0
# 3  1970-04-01  1970-04    4.617647           34.0
# 4  1970-05-01  1970-05    3.538462           13.0
# ..        ...      ...         ...            ...
# 56 1974-09-01  1974-09    4.666667            3.0
# 57 1974-10-01  1974-10    4.000000            5.0
# 58 1974-11-01  1974-11    4.857143            7.0
# 59 1974-12-01  1974-12    4.555556            9.0
# 60 1975-01-01  1975-01    5.000000            2.0
#
# [61 rows x 4 columns]

# %%
import matplotlib.pyplot as plt


# Graficar la serie temporal de avg_rating
plt.figure(figsize=(12, 6))
plt.plot(metrics_per_month['fecha'], metrics_per_month['avg_rating'], label='Avg Rating')
plt.title('Serie Temporal de Avg Rating')
plt.xlabel('Fecha')
plt.ylabel('Avg Rating')
plt.legend()
plt.show()

# %% [markdown]
# La gráfica muestra la evolución mensual de las calificaciones promedio (Avg Rating) de un producto, con fluctuaciones significativas entre periodos. Se observan picos máximos (calificación 5) en algunos meses, posiblemente debido a eventos positivos como mejoras o lanzamientos, y mínimos pronunciados (cercanos a 1), relacionados con problemas o quejas. No hay una tendencia clara (ni ascendente ni descendente), lo que sugiere una percepción variable influida por eventos específicos. La posible estacionalidad no es evidente a simple vista y requiere un análisis más profundo. El comportamiento refleja inestabilidad en la percepción del producto.

# %%
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
#Suavizado
metrics_per_month.set_index('fecha', inplace=True)
result = seasonal_decompose(metrics_per_month['avg_rating'])
result.plot()
plt.show()

# %% [markdown]
# Este gráfico descompone la serie temporal de las calificaciones promedio (avg_rating) en cuatro componentes:
#
# -Serie Original: Muestra las calificaciones observadas, con variaciones significativas a lo largo del tiempo, oscilando entre valores bajos (~1) y altos (~5).
#
#
# -Tendencia: Captura cambios a largo plazo. Se observa un aumento en 2020 y 2021, una caída en 2022, y una recuperación en 2023, reflejando variaciones en la percepción del producto.
#
#
# -Estacionalidad: Indica patrones repetitivos mensuales. Las oscilaciones regulares sugieren un comportamiento estacional, posiblemente vinculado a eventos recurrentes como lanzamientos o periodos de alta actividad.
#
#
# -Ruido: Representa eventos no explicados por la tendencia o estacionalidad. Los valores atípicos (e.g., picos negativos en 2020 y 2023) sugieren críticas inusuales o problemas temporales.
#
# Este análisis separa los factores principales que afectan las calificaciones, ayudando a entender la dinámica de la serie temporal y posibles puntos de mejora.

# %%
# Prueba de Dickey-Fuller 
adf_test = adfuller(metrics_per_month['avg_rating'])
print('ADF Statistic:', adf_test[0])
print('p-value:', adf_test[1])
print('Critical Values:', adf_test[4])
# Out:
# ADF Statistic: -6.511692654012152
# p-value: 1.0963644915108076e-08
# Critical Values: {'1%': -3.5443688564814813, '5%': -2.9110731481481484, '10%': -2.5931902777777776}

# %% [markdown]
# Dicky-Fuller:
#
# ADF Statistic: -5.8296 , com este valor buscamos que sea negativo para poder rechazar la hipotesis nula (serie no estacionaria), en este caso como podemos rechazarla
#
#
# p-value: es el nivel de significancia con el cual podemos rechazar la hipotesis nula, en este caso es bajísimo por lo cual podemos rechazar la h0(serie no estacionaria)
#
# Critical Values: Son nuestros umbrales para rechazar la hipotesis nula a diferentes niveles de confianza. Si el valor estadistico de ADF es menor que el valor critico correspondiente podemos rechazar la hipotesis nula para ese nivel de confianza.

# %%
# Tendencia
tendencia = result.trend

# Estacionalidad
estacionalidad = result.seasonal

# Ruido o residuos
residuos = result.resid

# Observados (serie original)
original = result.observed

# %%
print("Resumen de la tendencia:")
print(tendencia.describe())
# Out:
# Resumen de la tendencia:
# count    49.000000
# mean      4.013516
# std       0.212616
# min       3.578490
# 25%       3.885946
# 50%       4.059557
# 75%       4.186075
# max       4.313156
# Name: trend, dtype: float64

# %%
print("Resumen de la estacionalidad:")
estacionalidad # Primer ciclo
# Out:
# Resumen de la estacionalidad:
# fecha
# 1970-01-01    0.620509
# 1970-02-01    0.201721
# 1970-03-01    0.306325
# 1970-04-01   -0.773214
# 1970-05-01   -0.700463
#                 ...
# 1974-09-01    0.030122
# 1974-10-01   -0.005084
# 1974-11-01    0.338464
# 1974-12-01    0.103321
# 1975-01-01    0.620509
# Name: seasonal, Length: 61, dtype: float64

# %% [markdown]
# La estacionalidad detectada sugiere que algunos meses (como enero) suelen estar asociados con calificaciones más altas, mientras que otros (como abril y mayo) reflejan una tendencia recurrente a la baja. Esto podría deberse a:
#
# Factores externos (como lanzamientos o eventos de marketing).
# Comportamientos recurrentes de los usuarios en esos meses.

# %% [markdown]
# Los residuos en el análisis de series temporales se calculan como la diferencia entre los valores observados de la serie original y la suma de las componentes de tendencia y estacionalidad. Representan las variaciones no explicadas por estos patrones subyacentes.

# %%
residuos_std = np.std(result.resid.dropna())
outliers = result.resid[(result.resid > 2 * residuos_std) | (result.resid < -2 * residuos_std)]
print("Anomalías detectadas en residuos:")
print(outliers)
# Out:
# Anomalías detectadas en residuos:
# fecha
# 1971-04-01   -1.877775
# 1973-04-01    1.642214
# 1973-07-01   -2.401929
# 1974-05-01   -2.301769
# 1974-07-01    1.680779
# Name: resid, dtype: float64

# %%
residuos = result.resid
residuos_std = np.std(residuos.dropna())
anomalías = residuos[(residuos > 2 * residuos_std) | (residuos < -2 * residuos_std)]

# Graficar los residuos y las anomalías
plt.figure(figsize=(12, 6))
plt.plot(residuos, label='Residuos', color='blue')
plt.scatter(anomalías.index, anomalías, color='red', label='Anomalías')
plt.axhline(2 * residuos_std, color='green', linestyle='--', label='Umbral Superior')
plt.axhline(-2 * residuos_std, color='green', linestyle='--', label='Umbral Inferior')
plt.title('Residuos y Detección de Anomalías')
plt.legend()
plt.show()

# Mostrar las anomalías detectadas
print("Anomalías detectadas:")
print(anomalías)
# Out:
# Anomalías detectadas:
# fecha
# 1971-04-01   -1.877775
# 1973-04-01    1.642214
# 1973-07-01   -2.401929
# 1974-05-01   -2.301769
# 1974-07-01    1.680779
# Name: resid, dtype: float64

# %%
metrics_per_month.reset_index(inplace=True)
metrics_per_month = metrics_per_month.set_index(pd.DatetimeIndex(metrics_per_month['fecha'], freq='MS'))

train = metrics_per_month[metrics_per_month.index <= '1974-06-01']
test = metrics_per_month[metrics_per_month.index > '1974-06-01']

# Display the shapes of the resulting dataframes
print(f"Train data shape: {train.shape}")
print(f"Test data shape: {test.shape}")
# Out:
# Train data shape: (54, 4)
# Test data shape: (7, 4)

# %%
sgt.plot_acf(train['avg_rating'], lags = 24, zero = False)
plt.title("ACF Monthly Mean rating", size = 24)
plt.show()

# %%
sgt.plot_pacf(train['avg_rating'], lags = 24, zero = False, method = ('ols'))
plt.title("PACF Monthly Mean Rating", size = 24)
plt.autoscale()
plt.show()

# %%
q = [0, 10]
p = [0, 10, 12, 13, 21, 23]

# %%
from sklearn.metrics import mean_absolute_error
import itertools
import warnings

warnings.filterwarnings("ignore")


best_mae = float('inf')
best_p = None
best_q = None
best_model = None

for p, q in itertools.product(p, q):
    try:
        model = ARIMA(train['avg_rating'], order=(p, 0, q)) # Assuming d=1 as suggested by the ACF and PACF plots in your code. Adjust if needed.
        model_fit = model.fit()
        predictions = model_fit.forecast(steps=len(test))

        mae = mean_absolute_error(test['avg_rating'], predictions)

        if mae < best_mae:
            best_mae = mae
            best_p = p
            best_q = q
            best_model = model_fit

        print(f"p={p}, q={q}, MAE={mae}")

    except Exception as e:
        print(f"Error with p={p}, q={q}: {e}")
        continue

print(f"\nBest Model: p={best_p}, q={best_q}, MAE={best_mae}")
# Out:
# p=0, q=0, MAE=0.6727871051489295
# p=0, q=10, MAE=0.40408784935674635
# p=10, q=0, MAE=0.4309791547996031
# p=10, q=10, MAE=0.4750095427082269
# p=12, q=0, MAE=0.3646895240100217
# p=12, q=10, MAE=0.6332542113438764
# p=13, q=0, MAE=0.4072985061975542
# p=13, q=10, MAE=0.6027443727340083
# p=21, q=0, MAE=0.3939385451518035
# p=21, q=10, MAE=0.37625935073358857
# p=23, q=0, MAE=0.40110647172793484
# p=23, q=10, MAE=0.5562430850324115
#
# Best Model: p=12, q=0, MAE=0.3646895240100217

# %%
# Assuming best_model is already fitted as in the previous code.
predictions = best_model.forecast(steps=len(test))

plt.figure(figsize=(12, 6))
plt.plot(test['avg_rating'], label='True Values')
plt.plot(predictions, label='Predictions')
plt.title('Predicted vs True Values')
plt.xlabel('Date')
plt.ylabel('Avg Rating')
plt.legend()
plt.show()

# %%
predictions = best_model.forecast(steps=len(test))

extended_predictions = best_model.predict(start=0, end=len(metrics_per_month)-1)


plt.figure(figsize=(12, 6))


plt.plot(metrics_per_month.index, metrics_per_month['avg_rating'], label='Train', color='blue')



plt.plot(test.index, predictions, label='Predictions', color='red')

plt.title('Predicted vs True Values')
plt.xlabel('Date')
plt.ylabel('Avg Rating')
plt.xlim(train.index.min(), '1975-01-01') # Set x-axis limit to 1975-01-01
plt.legend()
plt.show()

# %%
s = [6, 12]
q = [0, 10]
p = [0, 10, 12, 13, 21, 23]
P = [0, 1, 2]
D = [0, 1]
Q = [0, 1, 2]
s = [6, 12]  # Seasonality

# %%
import itertools
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error
import warnings

warnings.filterwarnings("ignore")

best_mae = float('inf')
best_order = None
best_seasonal_order = None

for order in itertools.product(p, [0], q):
    for seasonal_order in itertools.product(P, D, Q, s):
        try:
            model = SARIMAX(train['avg_rating'], order=order, seasonal_order=seasonal_order)
            results = model.fit()


            model_fit = model.fit()
            predictions = model_fit.forecast(steps=len(test))

            mae = mean_absolute_error(test['avg_rating'], predictions)

            if mae < best_mae:
                best_mae = mae
                best_order = order
                best_seasonal_order = seasonal_order

            print(f"Order: {order}, Seasonal Order: {seasonal_order}, MAE: {mae}")

        except Exception as e:
            print(f"Error fitting model with order {order} and seasonal order {seasonal_order}: {e}")
            continue

print(f"\nBest model: Order={best_order}, Seasonal Order={best_seasonal_order}, MAE={best_mae}")
# Out:
# Order: (0, 0, 0), Seasonal Order: (0, 0, 0, 6), MAE: 4.654195011337869
# Order: (0, 0, 0), Seasonal Order: (0, 0, 0, 12), MAE: 4.654195011337869
# Order: (0, 0, 0), Seasonal Order: (0, 0, 1, 6), MAE: 3.207157530910824
# Order: (0, 0, 0), Seasonal Order: (0, 0, 1, 12), MAE: 3.1712559081532503
# Order: (0, 0, 0), Seasonal Order: (0, 0, 2, 6), MAE: 2.9059781004567844
# Order: (0, 0, 0), Seasonal Order: (0, 0, 2, 12), MAE: 1.9925012959191275
# Order: (0, 0, 0), Seasonal Order: (0, 1, 0, 6), MAE: 1.1621315192743764
# Order: (0, 0, 0), Seasonal Order: (0, 1, 0, 12), MAE: 0.7778963100391671
# Order: (0, 0, 0), Seasonal Order: (0, 1, 1, 6), MAE: 0.7061717076070853
# Order: (0, 0, 0), Seasonal Order: (0, 1, 1, 12), MAE: 0.6338684599934982
# Order: (0, 0, 0), Seasonal Order: (0, 1, 2, 6), MAE: 0.6148393191077055
# Order: (0, 0, 0), Seasonal Order: (0, 1, 2, 12), MAE: 0.611770719901255
# Order: (0, 0, 0), Seasonal Order: (1, 0, 0, 6), MAE: 1.2928550327604142
# Order: (0, 0, 0), Seasonal Order: (1, 0, 0, 12), MAE: 0.8801168994378112
# Order: (0, 0, 0), Seasonal Order: (1, 0, 1, 6), MAE: 0.7435322467429982
# Order: (0, 0, 0), Seasonal Order: (1, 0, 1, 12), MAE: 0.6604860246096907
# Order: (0, 0, 0), Seasonal Order: (1, 0, 2, 6), MAE: 0.6392135471944663
# Order: (0, 0, 0), Seasonal Order: (1, 0, 2, 12), MAE: 0.6403887918189186
# Order: (0, 0, 0), Seasonal Order: (1, 1, 0, 6), MAE: 0.9993536430921306
# Order: (0, 0, 0), Seasonal Order: (1, 1, 0, 12), MAE: 0.6131992321586716
# Order: (0, 0, 0), Seasonal Order: (1, 1, 1, 6), MAE: 0.6259657393008907
# Order: (0, 0, 0), Seasonal Order: (1, 1, 1, 12), MAE: 0.6157143246866978
# Order: (0, 0, 0), Seasonal Order: (1, 1, 2, 6), MAE: 0.6507607742343887
# Order: (0, 0, 0), Seasonal Order: (1, 1, 2, 12), MAE: 0.6698312044512583
# Order: (0, 0, 0), Seasonal Order: (2, 0, 0, 6), MAE: 1.0682207488480988
# Order: (0, 0, 0), Seasonal Order: (2, 0, 0, 12), MAE: 0.6965743879068488
# Order: (0, 0, 0), Seasonal Order: (2, 0, 1, 6), MAE: 0.6479094379859767
# Order: (0, 0, 0), Seasonal Order: (2, 0, 1, 12), MAE: 0.6429242609061058
# Order: (0, 0, 0), Seasonal Order: (2, 0, 2, 6), MAE: 0.6771712648226386
# Order: (0, 0, 0), Seasonal Order: (2, 0, 2, 12), MAE: 0.6703479285420749
# Order: (0, 0, 0), Seasonal Order: (2, 1, 0, 6), MAE: 0.8427598744353416
# Order: (0, 0, 0), Seasonal Order: (2, 1, 0, 12), MAE: 0.7109977250950751
# Order: (0, 0, 0), Seasonal Order: (2, 1, 1, 6), MAE: 0.621893346594687
# Order: (0, 0, 0), Seasonal Order: (2, 1, 1, 12), MAE: 0.6843169094958153
# Order: (0, 0, 0), Seasonal Order: (2, 1, 2, 6), MAE: 0.6122426055128434
# Order: (0, 0, 0), Seasonal Order: (2, 1, 2, 12), MAE: 0.6968406017790396
# Order: (0, 0, 10), Seasonal Order: (0, 0, 0, 6), MAE: 1.3669611522641978
# Order: (0, 0, 10), Seasonal Order: (0, 0, 0, 12), MAE: 1.3669611522641978
# Error fitting model with order (0, 0, 10) and seasonal order (0, 0, 1, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (0, 0, 10), Seasonal Order: (0, 0, 1, 12), MAE: 2.459826727471584
# Error fitting model with order (0, 0, 10) and seasonal order (0, 0, 2, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (0, 0, 10), Seasonal Order: (0, 0, 2, 12), MAE: 2.2665916101135033
# Order: (0, 0, 10), Seasonal Order: (0, 1, 0, 6), MAE: 0.771648672963501
# Order: (0, 0, 10), Seasonal Order: (0, 1, 0, 12), MAE: 1.1387598493853182
# Error fitting model with order (0, 0, 10) and seasonal order (0, 1, 1, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (0, 0, 10), Seasonal Order: (0, 1, 1, 12), MAE: 0.7554909172254628
# Error fitting model with order (0, 0, 10) and seasonal order (0, 1, 2, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (0, 0, 10), Seasonal Order: (0, 1, 2, 12), MAE: 0.6857367599363895
# Order: (0, 0, 10), Seasonal Order: (1, 0, 0, 6), MAE: 0.9863759716247312
# Order: (0, 0, 10), Seasonal Order: (1, 0, 0, 12), MAE: 1.469952659775009
# Error fitting model with order (0, 0, 10) and seasonal order (1, 0, 1, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (0, 0, 10), Seasonal Order: (1, 0, 1, 12), MAE: 1.1314064914089903
# Error fitting model with order (0, 0, 10) and seasonal order (1, 0, 2, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (0, 0, 10), Seasonal Order: (1, 0, 2, 12), MAE: 1.0493442504067492
# Order: (0, 0, 10), Seasonal Order: (1, 1, 0, 6), MAE: 0.6591660141679326
# Order: (0, 0, 10), Seasonal Order: (1, 1, 0, 12), MAE: 0.8822857712792522
# Error fitting model with order (0, 0, 10) and seasonal order (1, 1, 1, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (0, 0, 10), Seasonal Order: (1, 1, 1, 12), MAE: 0.7056362139868609
# Error fitting model with order (0, 0, 10) and seasonal order (1, 1, 2, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (0, 0, 10), Seasonal Order: (1, 1, 2, 12), MAE: 0.7739520325037997
# Order: (0, 0, 10), Seasonal Order: (2, 0, 0, 6), MAE: 1.1703584336152946
# Order: (0, 0, 10), Seasonal Order: (2, 0, 0, 12), MAE: 1.1212466829028778
# Error fitting model with order (0, 0, 10) and seasonal order (2, 0, 1, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (0, 0, 10), Seasonal Order: (2, 0, 1, 12), MAE: 1.1169614214467318
# Error fitting model with order (0, 0, 10) and seasonal order (2, 0, 2, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (0, 0, 10), Seasonal Order: (2, 0, 2, 12), MAE: 0.945335734324167
# Order: (0, 0, 10), Seasonal Order: (2, 1, 0, 6), MAE: 0.6572466136141751
# Order: (0, 0, 10), Seasonal Order: (2, 1, 0, 12), MAE: 0.7513459492682777
# Error fitting model with order (0, 0, 10) and seasonal order (2, 1, 1, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (0, 0, 10), Seasonal Order: (2, 1, 1, 12), MAE: 0.7209931783837158
# Error fitting model with order (0, 0, 10) and seasonal order (2, 1, 2, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (0, 0, 10), Seasonal Order: (2, 1, 2, 12), MAE: 0.7194655042152031
# Order: (10, 0, 0), Seasonal Order: (0, 0, 0, 6), MAE: 0.5633356731338839
# Order: (10, 0, 0), Seasonal Order: (0, 0, 0, 12), MAE: 0.5633356731338839
# Order: (10, 0, 0), Seasonal Order: (0, 0, 1, 6), MAE: 0.44597608832846447
# Order: (10, 0, 0), Seasonal Order: (0, 0, 1, 12), MAE: 0.5008289464890008
# Order: (10, 0, 0), Seasonal Order: (0, 0, 2, 6), MAE: 0.46104416446358387
# Order: (10, 0, 0), Seasonal Order: (0, 0, 2, 12), MAE: 0.5058567081014649
# Order: (10, 0, 0), Seasonal Order: (0, 1, 0, 6), MAE: 0.9978260292031548
# Order: (10, 0, 0), Seasonal Order: (0, 1, 0, 12), MAE: 0.9236050300014468
# Order: (10, 0, 0), Seasonal Order: (0, 1, 1, 6), MAE: 0.5446551566658919
# Order: (10, 0, 0), Seasonal Order: (0, 1, 1, 12), MAE: 0.7339745690367374
# Order: (10, 0, 0), Seasonal Order: (0, 1, 2, 6), MAE: 0.6022118753383275
# Order: (10, 0, 0), Seasonal Order: (0, 1, 2, 12), MAE: 0.8701660016116902
# Error fitting model with order (10, 0, 0) and seasonal order (1, 0, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 0), Seasonal Order: (1, 0, 0, 12), MAE: 0.4863905422412765
# Error fitting model with order (10, 0, 0) and seasonal order (1, 0, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 0), Seasonal Order: (1, 0, 1, 12), MAE: 0.560022756095801
# Error fitting model with order (10, 0, 0) and seasonal order (1, 0, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 0), Seasonal Order: (1, 0, 2, 12), MAE: 0.47409634024169617
# Error fitting model with order (10, 0, 0) and seasonal order (1, 1, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 0), Seasonal Order: (1, 1, 0, 12), MAE: 0.6619342992971181
# Error fitting model with order (10, 0, 0) and seasonal order (1, 1, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 0), Seasonal Order: (1, 1, 1, 12), MAE: 0.8852621918252507
# Error fitting model with order (10, 0, 0) and seasonal order (1, 1, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 0), Seasonal Order: (1, 1, 2, 12), MAE: 0.8015369007180599
# Error fitting model with order (10, 0, 0) and seasonal order (2, 0, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 0), Seasonal Order: (2, 0, 0, 12), MAE: 0.547969135627843
# Error fitting model with order (10, 0, 0) and seasonal order (2, 0, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 0), Seasonal Order: (2, 0, 1, 12), MAE: 0.46825167756031844
# Error fitting model with order (10, 0, 0) and seasonal order (2, 0, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 0), Seasonal Order: (2, 0, 2, 12), MAE: 0.502533522485063
# Error fitting model with order (10, 0, 0) and seasonal order (2, 1, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 0), Seasonal Order: (2, 1, 0, 12), MAE: 0.8696893285740259
# Error fitting model with order (10, 0, 0) and seasonal order (2, 1, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 0), Seasonal Order: (2, 1, 1, 12), MAE: 0.7821835384078476
# Error fitting model with order (10, 0, 0) and seasonal order (2, 1, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 0), Seasonal Order: (2, 1, 2, 12), MAE: 0.7581159186783984
# Order: (10, 0, 10), Seasonal Order: (0, 0, 0, 6), MAE: 0.6484242122094258
# Order: (10, 0, 10), Seasonal Order: (0, 0, 0, 12), MAE: 0.6484242122094258
# Error fitting model with order (10, 0, 10) and seasonal order (0, 0, 1, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (10, 0, 10), Seasonal Order: (0, 0, 1, 12), MAE: 0.49049871583188176
# Error fitting model with order (10, 0, 10) and seasonal order (0, 0, 2, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (10, 0, 10), Seasonal Order: (0, 0, 2, 12), MAE: 0.5586316786368242
# Order: (10, 0, 10), Seasonal Order: (0, 1, 0, 6), MAE: 1.1621312683245044
# Order: (10, 0, 10), Seasonal Order: (0, 1, 0, 12), MAE: 0.7778967361440262
# Error fitting model with order (10, 0, 10) and seasonal order (0, 1, 1, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (10, 0, 10), Seasonal Order: (0, 1, 1, 12), MAE: 0.7778978402244017
# Error fitting model with order (10, 0, 10) and seasonal order (0, 1, 2, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (10, 0, 10), Seasonal Order: (0, 1, 2, 12), MAE: 0.7778979768675366
# Error fitting model with order (10, 0, 10) and seasonal order (1, 0, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 10), Seasonal Order: (1, 0, 0, 12), MAE: 1.0924224911444935
# Error fitting model with order (10, 0, 10) and seasonal order (1, 0, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 10), Seasonal Order: (1, 0, 1, 12), MAE: 0.5948114382276101
# Error fitting model with order (10, 0, 10) and seasonal order (1, 0, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 10), Seasonal Order: (1, 0, 2, 12), MAE: 0.5152013193299648
# Error fitting model with order (10, 0, 10) and seasonal order (1, 1, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 10), Seasonal Order: (1, 1, 0, 12), MAE: 0.9010330965684096
# Error fitting model with order (10, 0, 10) and seasonal order (1, 1, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 10), Seasonal Order: (1, 1, 1, 12), MAE: 0.7778989443347955
# Error fitting model with order (10, 0, 10) and seasonal order (1, 1, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 10), Seasonal Order: (1, 1, 2, 12), MAE: 0.7778990809776133
# Error fitting model with order (10, 0, 10) and seasonal order (2, 0, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 10), Seasonal Order: (2, 0, 0, 12), MAE: 0.7512450465932072
# Error fitting model with order (10, 0, 10) and seasonal order (2, 0, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 10), Seasonal Order: (2, 0, 1, 12), MAE: 0.8482232903731894
# Error fitting model with order (10, 0, 10) and seasonal order (2, 0, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 10), Seasonal Order: (2, 0, 2, 12), MAE: 0.5153086887134899
# Error fitting model with order (10, 0, 10) and seasonal order (2, 1, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 10), Seasonal Order: (2, 1, 0, 12), MAE: 1.3786182556734927
# Error fitting model with order (10, 0, 10) and seasonal order (2, 1, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 10), Seasonal Order: (2, 1, 1, 12), MAE: 1.0509457022479354
# Error fitting model with order (10, 0, 10) and seasonal order (2, 1, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Order: (10, 0, 10), Seasonal Order: (2, 1, 2, 12), MAE: 0.777899217629124
# Order: (12, 0, 0), Seasonal Order: (0, 0, 0, 6), MAE: 0.5919213100014283
# Order: (12, 0, 0), Seasonal Order: (0, 0, 0, 12), MAE: 0.5919213100014283
# Order: (12, 0, 0), Seasonal Order: (0, 0, 1, 6), MAE: 0.5167764273975516
# Order: (12, 0, 0), Seasonal Order: (0, 0, 1, 12), MAE: 0.6303966529111589
# Order: (12, 0, 0), Seasonal Order: (0, 0, 2, 6), MAE: 0.602016639722301
# Order: (12, 0, 0), Seasonal Order: (0, 0, 2, 12), MAE: 0.589471772033307
# Order: (12, 0, 0), Seasonal Order: (0, 1, 0, 6), MAE: 0.7393822448600194
# Order: (12, 0, 0), Seasonal Order: (0, 1, 0, 12), MAE: 0.6936930096813368
# Order: (12, 0, 0), Seasonal Order: (0, 1, 1, 6), MAE: 0.5343491466469401
# Order: (12, 0, 0), Seasonal Order: (0, 1, 1, 12), MAE: 0.6888916377423842
# Order: (12, 0, 0), Seasonal Order: (0, 1, 2, 6), MAE: 0.6714473888320371
# Order: (12, 0, 0), Seasonal Order: (0, 1, 2, 12), MAE: 0.7825499630096822
# Error fitting model with order (12, 0, 0) and seasonal order (1, 0, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (1, 0, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (1, 0, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (1, 0, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (1, 0, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (1, 0, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (1, 1, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (1, 1, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (1, 1, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (1, 1, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (1, 1, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (1, 1, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (2, 0, 0, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (2, 0, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (2, 0, 1, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (2, 0, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (2, 0, 2, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (2, 0, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (2, 1, 0, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (2, 1, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (2, 1, 1, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (2, 1, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (2, 1, 2, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 0) and seasonal order (2, 1, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Order: (12, 0, 10), Seasonal Order: (0, 0, 0, 6), MAE: 0.7901928791877534
# Order: (12, 0, 10), Seasonal Order: (0, 0, 0, 12), MAE: 0.7901928791877534
# Error fitting model with order (12, 0, 10) and seasonal order (0, 0, 1, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (12, 0, 10), Seasonal Order: (0, 0, 1, 12), MAE: 0.5335194310240203
# Error fitting model with order (12, 0, 10) and seasonal order (0, 0, 2, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (12, 0, 10), Seasonal Order: (0, 0, 2, 12), MAE: 0.5664209453225999
# Order: (12, 0, 10), Seasonal Order: (0, 1, 0, 6), MAE: 1.1621311554439562
# Order: (12, 0, 10), Seasonal Order: (0, 1, 0, 12), MAE: 1.0529162563608059
# Error fitting model with order (12, 0, 10) and seasonal order (0, 1, 1, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (12, 0, 10), Seasonal Order: (0, 1, 1, 12), MAE: 0.7898865543277935
# Error fitting model with order (12, 0, 10) and seasonal order (0, 1, 2, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (12, 0, 10), Seasonal Order: (0, 1, 2, 12), MAE: 0.7987120443295032
# Error fitting model with order (12, 0, 10) and seasonal order (1, 0, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (1, 0, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (1, 0, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (1, 0, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (1, 0, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (1, 0, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (1, 1, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (1, 1, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (1, 1, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (1, 1, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (1, 1, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (1, 1, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (2, 0, 0, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (2, 0, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (2, 0, 1, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (2, 0, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (2, 0, 2, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (2, 0, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (2, 1, 0, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (2, 1, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (2, 1, 1, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (2, 1, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (2, 1, 2, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (12, 0, 10) and seasonal order (2, 1, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Order: (13, 0, 0), Seasonal Order: (0, 0, 0, 6), MAE: 0.5934022747453065
# Order: (13, 0, 0), Seasonal Order: (0, 0, 0, 12), MAE: 0.5934022747453065
# Order: (13, 0, 0), Seasonal Order: (0, 0, 1, 6), MAE: 0.5273538950063931
# Order: (13, 0, 0), Seasonal Order: (0, 0, 1, 12), MAE: 0.591245187721684
# Order: (13, 0, 0), Seasonal Order: (0, 0, 2, 6), MAE: 0.5749796667112843
# Order: (13, 0, 0), Seasonal Order: (0, 0, 2, 12), MAE: 0.5489516941137734
# Order: (13, 0, 0), Seasonal Order: (0, 1, 0, 6), MAE: 0.783788460296175
# Order: (13, 0, 0), Seasonal Order: (0, 1, 0, 12), MAE: 0.7823295706533322
# Order: (13, 0, 0), Seasonal Order: (0, 1, 1, 6), MAE: 0.6869666066821986
# Order: (13, 0, 0), Seasonal Order: (0, 1, 1, 12), MAE: 0.7847799745365889
# Order: (13, 0, 0), Seasonal Order: (0, 1, 2, 6), MAE: 0.8789628490209646
# Order: (13, 0, 0), Seasonal Order: (0, 1, 2, 12), MAE: 0.8724384251352139
# Error fitting model with order (13, 0, 0) and seasonal order (1, 0, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (1, 0, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (1, 0, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (1, 0, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (1, 0, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (1, 0, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (1, 1, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (1, 1, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (1, 1, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (1, 1, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (1, 1, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (1, 1, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (2, 0, 0, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (2, 0, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (2, 0, 1, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (2, 0, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (2, 0, 2, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (2, 0, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (2, 1, 0, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (2, 1, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (2, 1, 1, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (2, 1, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (2, 1, 2, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 0) and seasonal order (2, 1, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Order: (13, 0, 10), Seasonal Order: (0, 0, 0, 6), MAE: 0.8474951683760562
# Order: (13, 0, 10), Seasonal Order: (0, 0, 0, 12), MAE: 0.8474951683760562
# Error fitting model with order (13, 0, 10) and seasonal order (0, 0, 1, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (13, 0, 10), Seasonal Order: (0, 0, 1, 12), MAE: 0.5817228280181912
# Error fitting model with order (13, 0, 10) and seasonal order (0, 0, 2, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (13, 0, 10), Seasonal Order: (0, 0, 2, 12), MAE: 0.5056018713251857
# Order: (13, 0, 10), Seasonal Order: (0, 1, 0, 6), MAE: 1.1621311620624628
# Order: (13, 0, 10), Seasonal Order: (0, 1, 0, 12), MAE: 1.299148873754199
# Error fitting model with order (13, 0, 10) and seasonal order (0, 1, 1, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (13, 0, 10), Seasonal Order: (0, 1, 1, 12), MAE: 1.1082978706274393
# Error fitting model with order (13, 0, 10) and seasonal order (0, 1, 2, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (13, 0, 10), Seasonal Order: (0, 1, 2, 12), MAE: 0.894471279278321
# Error fitting model with order (13, 0, 10) and seasonal order (1, 0, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (1, 0, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (1, 0, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (1, 0, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (1, 0, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (1, 0, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (1, 1, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (1, 1, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (1, 1, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (1, 1, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (1, 1, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (1, 1, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (2, 0, 0, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (2, 0, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (2, 0, 1, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (2, 0, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (2, 0, 2, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (2, 0, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (2, 1, 0, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (2, 1, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (2, 1, 1, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (2, 1, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (2, 1, 2, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (13, 0, 10) and seasonal order (2, 1, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Order: (21, 0, 0), Seasonal Order: (0, 0, 0, 6), MAE: 0.4531681411653516
# Order: (21, 0, 0), Seasonal Order: (0, 0, 0, 12), MAE: 0.4531681411653516
# Order: (21, 0, 0), Seasonal Order: (0, 0, 1, 6), MAE: 0.6477175239552915
# Order: (21, 0, 0), Seasonal Order: (0, 0, 1, 12), MAE: 0.4265750313116913
# Order: (21, 0, 0), Seasonal Order: (0, 0, 2, 6), MAE: 0.428007885907069
# Order: (21, 0, 0), Seasonal Order: (0, 0, 2, 12), MAE: 0.43566457790809654
# Order: (21, 0, 0), Seasonal Order: (0, 1, 0, 6), MAE: 0.728965839238725
# Order: (21, 0, 0), Seasonal Order: (0, 1, 0, 12), MAE: 0.7778972723107414
# Order: (21, 0, 0), Seasonal Order: (0, 1, 1, 6), MAE: 0.9453163700580137
# Order: (21, 0, 0), Seasonal Order: (0, 1, 1, 12), MAE: 0.7778983763922652
# Order: (21, 0, 0), Seasonal Order: (0, 1, 2, 6), MAE: 0.7833705938660636
# Order: (21, 0, 0), Seasonal Order: (0, 1, 2, 12), MAE: 0.7778985130349315
# Error fitting model with order (21, 0, 0) and seasonal order (1, 0, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (1, 0, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (1, 0, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (1, 0, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (1, 0, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (1, 0, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (1, 1, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (1, 1, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (1, 1, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (1, 1, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (1, 1, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (1, 1, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (2, 0, 0, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (2, 0, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (2, 0, 1, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (2, 0, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (2, 0, 2, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (2, 0, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (2, 1, 0, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (2, 1, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (2, 1, 1, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (2, 1, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (2, 1, 2, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 0) and seasonal order (2, 1, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Order: (21, 0, 10), Seasonal Order: (0, 0, 0, 6), MAE: 0.47030284142518736
# Order: (21, 0, 10), Seasonal Order: (0, 0, 0, 12), MAE: 0.47030284142518736
# Error fitting model with order (21, 0, 10) and seasonal order (0, 0, 1, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (21, 0, 10), Seasonal Order: (0, 0, 1, 12), MAE: 0.49063197067566194
# Error fitting model with order (21, 0, 10) and seasonal order (0, 0, 2, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (21, 0, 10), Seasonal Order: (0, 0, 2, 12), MAE: 0.4405025984794993
# Order: (21, 0, 10), Seasonal Order: (0, 1, 0, 6), MAE: 1.0334837037598088
# Order: (21, 0, 10), Seasonal Order: (0, 1, 0, 12), MAE: 1.358094250072344
# Error fitting model with order (21, 0, 10) and seasonal order (0, 1, 1, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (21, 0, 10), Seasonal Order: (0, 1, 1, 12), MAE: 1.2906494259434775
# Error fitting model with order (21, 0, 10) and seasonal order (0, 1, 2, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (21, 0, 10), Seasonal Order: (0, 1, 2, 12), MAE: 1.2827943654897613
# Error fitting model with order (21, 0, 10) and seasonal order (1, 0, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (1, 0, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (1, 0, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (1, 0, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (1, 0, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (1, 0, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (1, 1, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (1, 1, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (1, 1, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (1, 1, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (1, 1, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (1, 1, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (2, 0, 0, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (2, 0, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (2, 0, 1, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (2, 0, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (2, 0, 2, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (2, 0, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (2, 1, 0, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (2, 1, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (2, 1, 1, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (2, 1, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (2, 1, 2, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (21, 0, 10) and seasonal order (2, 1, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Order: (23, 0, 0), Seasonal Order: (0, 0, 0, 6), MAE: 0.4299976135559106
# Order: (23, 0, 0), Seasonal Order: (0, 0, 0, 12), MAE: 0.4299976135559106
# Order: (23, 0, 0), Seasonal Order: (0, 0, 1, 6), MAE: 0.39049699918098907
# Order: (23, 0, 0), Seasonal Order: (0, 0, 1, 12), MAE: 0.4007469713464798
# Order: (23, 0, 0), Seasonal Order: (0, 0, 2, 6), MAE: 0.5318493022429945
# Order: (23, 0, 0), Seasonal Order: (0, 0, 2, 12), MAE: 0.43156811161359904
# Order: (23, 0, 0), Seasonal Order: (0, 1, 0, 6), MAE: 0.7247688808750172
# Order: (23, 0, 0), Seasonal Order: (0, 1, 0, 12), MAE: 0.7778973864393057
# Order: (23, 0, 0), Seasonal Order: (0, 1, 1, 6), MAE: 0.9706714281533558
# Order: (23, 0, 0), Seasonal Order: (0, 1, 1, 12), MAE: 0.7778984905204654
# Order: (23, 0, 0), Seasonal Order: (0, 1, 2, 6), MAE: 0.7702235745876929
# Order: (23, 0, 0), Seasonal Order: (0, 1, 2, 12), MAE: 0.7778986271626546
# Error fitting model with order (23, 0, 0) and seasonal order (1, 0, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (1, 0, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (1, 0, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (1, 0, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (1, 0, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (1, 0, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (1, 1, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (1, 1, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (1, 1, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (1, 1, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (1, 1, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (1, 1, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (2, 0, 0, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (2, 0, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (2, 0, 1, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (2, 0, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (2, 0, 2, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (2, 0, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (2, 1, 0, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (2, 1, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (2, 1, 1, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (2, 1, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (2, 1, 2, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 0) and seasonal order (2, 1, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Order: (23, 0, 10), Seasonal Order: (0, 0, 0, 6), MAE: 0.4812270270796854
# Order: (23, 0, 10), Seasonal Order: (0, 0, 0, 12), MAE: 0.4812270270796854
# Error fitting model with order (23, 0, 10) and seasonal order (0, 0, 1, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (23, 0, 10), Seasonal Order: (0, 0, 1, 12), MAE: 0.5510359010523479
# Error fitting model with order (23, 0, 10) and seasonal order (0, 0, 2, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (23, 0, 10), Seasonal Order: (0, 0, 2, 12), MAE: 0.7945333045415607
# Order: (23, 0, 10), Seasonal Order: (0, 1, 0, 6), MAE: 1.1428236309041544
# Order: (23, 0, 10), Seasonal Order: (0, 1, 0, 12), MAE: 1.5236194021789007
# Error fitting model with order (23, 0, 10) and seasonal order (0, 1, 1, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (23, 0, 10), Seasonal Order: (0, 1, 1, 12), MAE: 1.26139196771927
# Error fitting model with order (23, 0, 10) and seasonal order (0, 1, 2, 6): Invalid model: moving average lag(s) {6} are in both the seasonal and non-seasonal moving average components.
# Order: (23, 0, 10), Seasonal Order: (0, 1, 2, 12), MAE: 1.2124808653726238
# Error fitting model with order (23, 0, 10) and seasonal order (1, 0, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (1, 0, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (1, 0, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (1, 0, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (1, 0, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (1, 0, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (1, 1, 0, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (1, 1, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (1, 1, 1, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (1, 1, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (1, 1, 2, 6): Invalid model: autoregressive lag(s) {6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (1, 1, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (2, 0, 0, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (2, 0, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (2, 0, 1, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (2, 0, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (2, 0, 2, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (2, 0, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (2, 1, 0, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (2, 1, 0, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (2, 1, 1, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (2, 1, 1, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (2, 1, 2, 6): Invalid model: autoregressive lag(s) {12, 6} are in both the seasonal and non-seasonal autoregressive components.
# Error fitting model with order (23, 0, 10) and seasonal order (2, 1, 2, 12): Invalid model: autoregressive lag(s) {12} are in both the seasonal and non-seasonal autoregressive components.
#
# Best model: Order=(23, 0, 0), Seasonal Order=(0, 0, 1, 6), MAE=0.39049699918098907

# %%
best_model = SARIMAX(train['avg_rating'], order=best_order, seasonal_order=best_seasonal_order)
best_model = best_model.fit()
predictions = best_model.forecast(steps=len(test))

extended_predictions = best_model.predict(start=0, end=len(metrics_per_month)-1)


plt.figure(figsize=(12, 6))

plt.plot(metrics_per_month.index, metrics_per_month['avg_rating'], label='Train', color='blue')



plt.plot(test.index, predictions, label='Predictions', color='red')

plt.title('Predicted vs True Values')
plt.xlabel('Date')
plt.ylabel('Avg Rating')
plt.xlim(train.index.min(), '1975-01-01') # Set x-axis limit to 1975-01-01
plt.legend()
plt.show()

# %%
data = pd.read_csv('/content/drive/MyDrive/ProyectoDDCGrupoA/dataprocessed/datos_preprocesados_2.csv')
data
# Out:
#          model_name  Price (Dollar)  Storage (GB)  \
# 0         iPhone XS          182.00            64
# 1     iPhone XS Max          234.95            64
# 2    iPhone 15 Plus         1098.95           128
# 3         iPhone 11          599.00            64
# 4     iPhone 12 Pro          840.13           128
# ..              ...             ...           ...
# 585       iPhone XR          168.39            64
# 586       iPhone XR          181.00            64
# 587       iPhone XR          181.00            64
# 588       iPhone XR          168.39            64
# 589       iPhone XR          181.00            64
#
#                                                 review   timestamp  stars  \
# 0    i received the phone within 2 days of ordering...  2022-02-05      1
# 1    6 months later update - still acts like i boug...  2019-12-20      5
# 2    phone is great but the price is $200 above msr...  2023-11-27      1
# 3         fast shipping, very nice phone!\r\nread more  2020-07-28      5
# 4              amazing defenitly worth it\r\nread more  2020-11-05      5
# ..                                                 ...         ...    ...
# 585  got it to replace my 13 year olds xr in a pinc...  2024-09-15      5
# 586  my little niece is so inlove with this phone😌 ...  2024-09-18      5
# 587                             great buy\r\nread more  2024-09-20      5
# 588  hey guys, so i ordered this phone on the 19th ...  2024-09-22      5
# 589  no complaints, arrived in excellent condition ...  2024-09-30      5
#
#                country language  \
# 0    the United States       en
# 1    the United States       en
# 2    the United States       en
# 3    the United States       en
# 4    the United States       en
# ..                 ...      ...
# 585  the United States       en
# 586  the United States       en
# 587  the United States       en
# 588  the United States       en
# 589  the United States       en
#
#                                              tk_review    timestamp_nanosec  \
# 0    ['received', 'phone', 'within', 'day', 'orderi...  1644019200000000000
# 1    ['month', 'later', 'update', 'still', 'act', '...  1576800000000000000
# 2    ['phone', 'great', 'price', '200', 'msrp', 're...  1701043200000000000
# 3        ['fast', 'shipping', 'nice', 'phone', 'read']  1595894400000000000
# 4            ['amazing', 'defenitly', 'worth', 'read']  1604534400000000000
# ..                                                 ...                  ...
# 585  ['got', 'replace', 'year', 'old', 'pinch', 'ba...  1726358400000000000
# 586  ['little', 'niece', 'inlove', 'phone', 'brough...  1726617600000000000
# 587                           ['great', 'buy', 'read']  1726790400000000000
# 588  ['hey', 'guy', 'ordered', 'phone', '19th', 'go...  1726963200000000000
# 589  ['complaint', 'arrived', 'excellent', 'conditi...  1727654400000000000
#
#      normalized_timestamp_nanosec timestamp_formatted
# 0                               0          01/01/1970
# 1                               0          01/01/1970
# 2                               0          01/01/1970
# 3                               0          01/01/1970
# 4                               0          01/01/1970
# ..                            ...                 ...
# 585            157161600000000000          25/12/1974
# 586            157420800000000000          28/12/1974
# 587            157593600000000000          30/12/1974
# 588            157766400000000000          01/01/1975
# 589            158457600000000000          09/01/1975
#
# [590 rows x 12 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(stop_words=None)
dtm = vectorizer.fit_transform(data['tk_review'])

word_freq = pd.DataFrame({
    'palabra': vectorizer.get_feature_names_out(),
    'frecuencia': dtm.sum(axis=0).A1
}).sort_values(by='frecuencia', ascending=False)

word_freq.head(50)
# Out:
#           palabra  frecuencia
# 2244        phone        1241
# 2442         read         604
# 377       battery         448
# 1655       iphone         408
# 2038          new         345
# 2684      scratch         242
# 1406        great         239
# 696     condition         233
# 1382         good         222
# 2112          one         222
# 233        amazon         221
# 2690       screen         200
# 1776         like         199
# 275         apple         194
# 522          came         181
# 3437         work         180
# 3452        would         170
# 832           day         152
# 2357          pro         148
# 3143         time         144
# 2552      renewed         138
# 465         brand         137
# 1353          get         135
# 1661        issue         134
# 3             100         133
# 1133    excellent         130
# 2727       seller         129
# 1767         life         129
# 515           buy         122
# 2512  refurbished         117
# 1895          max         115
# 353          back         113
# 523        camera         109
# 1469       health         107
# 224          also         107
# 1115         even         106
# 1246        first         106
# 3392         well         103
# 1815         look         101
# 2341        price         100
# 1449        happy         100
# 2367      product          98
# 1387          got          93
# 2398     purchase          92
# 2227      perfect          91
# 2602       return          90
# 1123   everything          90
# 586       charger          86
# 457        bought          85
# 2452       really          85

# %%
import matplotlib.pyplot as plt

top_words = word_freq.head(10)
plt.bar(top_words['palabra'], top_words['frecuencia'])
plt.title('Palabras más frecuentes')
plt.xlabel('Palabra')
plt.ylabel('Frecuencia')
plt.show()

# %%
top_words = word_freq.head(15)['palabra'].tolist()
word_freq_by_month[top_words].plot(figsize=(10, 6))
plt.title('Frecuencia de palabras clave a lo largo del tiempo')
plt.xlabel('Mes')
plt.ylabel('Frecuencia')
plt.legend(top_words)
plt.show()

# %% [markdown]
# Este gráfico muestra la relación entre las calificaciones promedio (avg_rating) y la frecuencia de palabras negativas (negative_words) a lo largo del tiempo. Se observa que las calificaciones tienden a ser bajas en periodos donde la frecuencia de palabras negativas es más alta (e.g., puntos cercanos a valores negativos en la escala secundaria). Los picos negativos en las palabras suelen coincidir con caídas abruptas en las calificaciones, lo que sugiere que los comentarios negativos están relacionados con periodos de insatisfacción del usuario. Sin embargo, hay momentos donde la relación es menos clara, indicando la necesidad de analizar otras variables.

# %% [markdown]
# #LDA#

# %%
from sklearn.decomposition import LatentDirichletAllocation

# Configurar y entrenar el modelo LDA para identificar tópicos
lda = LatentDirichletAllocation(n_components=64, random_state=42)
lda.fit(dtm)
# Out:
# LatentDirichletAllocation(n_components=64, random_state=42)

# %%
topic_distribution = lda.transform(dtm)
data['mes'] = data['timestamp_formatted'].dt.to_period('M')
topic_by_month = data.groupby('mes')[[f'Topic_{i}' for i in range(lda.n_components)]].mean()

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import matplotlib.pyplot as plt
import pandas as pd

vectorizer = CountVectorizer(stop_words='english')
dtm = vectorizer.fit_transform(data['tk_review'])

# Ajustar el modelo LDA
lda = LatentDirichletAllocation(n_components=5, random_state=42)
lda.fit(dtm)

# Mostrar los topics que hemos detectado
for topic_idx, topic in enumerate(lda.components_):
    print(f"Tópico {topic_idx}: {[vectorizer.get_feature_names_out()[i] for i in topic.argsort()[:-11:-1]]}")

# Relación de tópicos con el tiempo
data['mes'] = pd.to_datetime(data['timestamp']).dt.to_period('M')
topic_distribution = lda.transform(dtm)
topic_df = pd.DataFrame(topic_distribution, columns=[f'Topic_{i}' for i in range(lda.n_components)])
data_with_topics = pd.concat([data, topic_df], axis=1)

topics_by_month = data_with_topics.groupby('mes')[[f'Topic_{i}' for i in range(lda.n_components)]].mean()
topics_by_month.plot(figsize=(10, 6))
plt.title('Distribución de tópicos en el tiempo')
plt.xlabel('Mes')
plt.ylabel('Proporción promedio')
plt.legend([f'Tópico {i}' for i in range(lda.n_components)])
plt.show()
# Out:
# Tópico 0: ['phone', 'iphone', 'battery', 'read', 'new', 'apple', 'amazon', 'pro', 'great', 'max']
# Tópico 1: ['phone', 'read', 'battery', 'scratch', 'new', 'condition', 'seller', 'iphone', 'screen', 'brand']
# Tópico 2: ['phone', 'read', 'great', 'battery', 'good', 'came', 'condition', 'work', 'new', 'screen']
# Tópico 3: ['phone', 'amazon', 'read', 'iphone', 'return', 'work', 'told', 'refund', 'took', 'apple']
# Tópico 4: ['phone', 'iphone', 'like', 'screen', 'new', 'day', 'brand', 'money', 'read', 'buying']
