# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/hugo/Documents/Github/ProyectoDDCGrupoA/dataprocessed/datos_preprocesados.csv')
df
# Out:
#     timestamp_formatted         model_name  Price (Dollar)  Storage (GB)  \
# 0            01/01/1970  iPhone 13 Pro Max         1049.70           128
# 1            01/01/1970         13 Pro Max          579.99           128
# 2            01/01/1970          iPhone 13          767.14           128
# 3            01/01/1970          iPhone 14          552.01           128
# 4            01/01/1970          iPhone SE          199.99            16
# ..                  ...                ...             ...           ...
# 585          25/12/1974          iPhone XR          168.39            64
# 586          28/12/1974          iPhone XR          181.00            64
# 587          30/12/1974          iPhone XR          181.00            64
# 588          01/01/1975          iPhone XR          168.39            64
# 589          09/01/1975          iPhone XR          181.00            64
#
#                                                 review   timestamp  stars  \
# ...
